# %%
import os
from IPython.display import Image

save_dir = os.path.abspath('Models/')

# %% [markdown]
# For some odd reason these plots did not want to display while training. So we have added them here for easier viewing.

# %% [markdown]
# ## Model 1

# %%
m_id = 1
Image(os.path.join(save_dir, f'{m_id}/model.png'))

# %% [markdown]
# ## Model 2

# %%
m_id = 2
Image(os.path.join(save_dir, f'{m_id}/model.png'))

# %% [markdown]
# ## Model 3

# %%
m_id = 3
Image(os.path.join(save_dir, f'{m_id}/model.png'))

# %% [markdown]
# ## Model 4

# %%
m_id = 4
Image(os.path.join(save_dir, f'{m_id}/model.png'))

# %% [markdown]
# ## Model 5

# %%
m_id = 5
Image(os.path.join(save_dir, f'{m_id}/model.png'))
